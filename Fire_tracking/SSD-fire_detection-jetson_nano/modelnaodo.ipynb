# %%
# !nvidia-smi
# Out:
# Mon May 17 05:44:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Draft/jetson-nano-fire-detection
# Out:
# /content/drive/MyDrive/Draft/jetson-nano-fire-detection

# %%
# !python train.py fire/nanodet_fire.yml
# Out:
# [root][05-17 05:45:32]INFO:Using Tensorboard, logs will be saved in ./fire/logs
# 2021-05-17 05:45:32.804416: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [root][05-17 05:45:34]INFO:Creating model...
# model size is  1.0x
# init weights...
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to /root/.cache/torch/hub/checkpoints/shufflenetv2_x1-5666bf0f80.pth
# 100% 8.79M/8.79M [00:00<00:00, 67.1MB/s]
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize Lite GFL Head.
# [root][05-17 05:45:34]INFO:Setting up data...
# [root][05-17 05:45:34]INFO:loading annotations into memory...
# [root][05-17 05:45:43]INFO:Found 2343 annotation files.
# [root][05-17 05:57:23]INFO:Load 2343 xml files and 2986 boxes
# [root][05-17 05:57:23]INFO:Done (t=708.87s)
# creating index...
# index created!
# ...

# %%
print('Done')
# Out:
# Done
